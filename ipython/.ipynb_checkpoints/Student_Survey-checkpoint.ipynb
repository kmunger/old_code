# %%
import pandas as pd
import numpy as np

d=pd.read_csv('/Users/briand/Desktop/ds course/datasets/survey.csv',header=0,index_col=0)
prof=['profile_{}'.format(k+1) for k in range(7)] 
cs=['cs_java','cs_c','cs_r','cs_sas']
dpro=d[prof]
descr=['Viz','CS','Math','Stats','ML','Bus','Com']

# %%
'''
Data Visualization	Computer Science	Mathematics	Statistics	Machine Learning	Business Strategy	Communication
profile_1	profile_2	profile_3	profile_4	profile_5	profile_6	profile_7
'''
dpro.corr()
# Out:
#            profile_1  profile_2  profile_3  profile_4  profile_5  profile_6  \
# profile_1   1.000000   0.152359  -0.300290   0.037265   0.252176   0.331251
# profile_2   0.152359   1.000000  -0.043024  -0.323509   0.268947   0.028442
# profile_3  -0.300290  -0.043024   1.000000   0.553152   0.047042  -0.197754
# profile_4   0.037265  -0.323509   0.553152   1.000000   0.044143  -0.012377
# profile_5   0.252176   0.268947   0.047042   0.044143   1.000000   0.013436
# profile_6   0.331251   0.028442  -0.197754  -0.012377   0.013436   1.000000
# profile_7   0.214947   0.076398  -0.222641  -0.091014  -0.034947   0.565198
#
#            profile_7
# profile_1   0.214947
# profile_2   0.076398
# profile_3  -0.222641
# profile_4  -0.091014
# profile_5  -0.034947
# profile_6   0.565198
# profile_7   1.000000

# %%
'''
Plot histograms of ds profile
'''

fig=plt.figure()
for i in range(7):
    plt.subplot(3,4,i+1)
    hist(dpro[prof[i]])
    plt.title(descr[i])

#fig.tight_layout()

# %%
'''
ds profile by years of experience
'''
d[['WorkExp']+prof].groupby(['WorkExp']).agg([len,np.mean])
# Out:
#          profile_1            profile_2            profile_3            \
#                len      mean        len      mean        len      mean
# WorkExp
# 1               24  2.666667         24  4.041667         24  6.958333
# 2                5  2.800000          5  4.400000          5  6.800000
# 3                5  3.600000          5  4.000000          5  5.800000
# 4               12  4.000000         12  5.666667         12  5.333333
#
#          profile_4            profile_5            profile_6            \
#                len      mean        len      mean        len      mean
# WorkExp
# 1               24  6.583333         24  3.166667         24  3.125000
# 2                5  6.400000          5  3.200000          5  3.400000
# 3                5  5.000000          5  2.600000          5  6.200000
# 4               12  4.750000         12  2.333333         12  5.416667
#
#          profile_7
#                len      mean
# WorkExp
# 1               24  5.458333
# 2                5  6.200000
# 3                5  6.000000
# 4               12  6.500000

# %%
'''
Length of long answer by communication skill
'''
d[['profile_7','LenAnswer']].groupby(['profile_7']).agg([len,np.mean])
# Out:
#            LenAnswer
#                  len        mean
# profile_7
# 1                  1  382.000000
# 2                  1  740.000000
# 3                  4  729.750000
# 4                  3  112.666667
# 5                 13  457.538462
# 6                  4  546.750000
# 7                 11  780.454545
# 8                  6  448.666667
# 9                  1  373.000000
# 10                 2  740.500000
